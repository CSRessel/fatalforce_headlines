# %%
import pickle
import re

# %%
with open("filtered_headlines.pickle", 'rb') as infile:
    dataset = pickle.load(infile)

print(len(dataset))
# Out:
# 955

# %%
# TODO: "gunman", "SWAT", "ATF agent", "border patrol", "sheriff", any keyword followed immediately by comma

# hand-curated dictionaries of expected participant-referential phrases (PRP's)
POLICE_KWORDS = {r"(?<!police )officer", r"police(?! officer)", r"police officer", r"deput(?:y|ies)", \
                 r"(?:^|\W)cop(?:$|\W)", r"trooper", r"captain", r"(?:[a-z]\.?)*p\.?d\.?(?:$|\W)", r"marshal", \
                 r"(?:^|\W)d\.?e\.?a\.?(?:$|\W)", r"border patrol", r"\Ws\.?w\.?a\.?t\W"}
DECEAS_KWORDS = {"kidnapper", r"suspect(?:|s)(?:\W|$)", "person", r"(?:^|\W)(?:man|woman)(?:$|\W)", r"(?:^|\W)(?:men|women)(?:$|\W)", \
                 r"(?:^|\W)guy(?:$|\W)", r"(?:^|\W)boy(?:$|\W)", r"(?:^|\W)girl(?:$|\W)", r"[0-9]{1,2}(?:-| )year(?:-| )old", r"teen", \
                 r"family(?:-| )member", r"patient", r"inmate", r"guard", r"driver", r"passenger", \
                 r"veteran", r"killer", r"victim", r"father", r"mother", r"fugitive", \
                 r"hostage(?:-| )taker", r"dealer", r"rapper"}
COUNTERS = {r"[1-9]\sdead", r"[0-9]{1,2}\b", r"one", r"two", r"three", r"four", r"five", r"six",\
            r"seven", r"eight", r"nine", r"ten"}
PRONOUNS = {r"they", r"them", r"he", r"him", r"she", r"her"}
WEIRD = r"[^\w &:;,.\-—|/\"“”'‘’\s]"
DEMOGRAPHICS = [r"age", r"gender", r"race", r"state"]

# exceptions:
#     Ex-Alabama trooper shoots DA in face, is killed by police
#     Former police captain shot and killed by officer in northeast Fresno | The Fresno Bee

# %%
# small data correction
random_artifact = r"(?:\u00e2\u0080\u0098|\u00e2\u0080\u0099)"
for datapoint in dataset:
    if re.search(random_artifact, datapoint["headline"]):
        headline = re.sub(random_artifact, "", datapoint["headline"])
        datapoint["headline"] = headline

# %%
# add label fields to datapoints

from copy import deepcopy

labeled_dataset = deepcopy(dataset)

for d in labeled_dataset:
    
    h = d["headline"]
    terms = []
    
    for kw in DECEAS_KWORDS:
        if re.search(kw, h, re.IGNORECASE):
            terms.append(kw)
            
    assert(len(terms) <= 3) # at most 3 labels
    terms.extend([''] * (3 - len(terms))) # pad to length 3
    assert(len(terms) == 3)
    
    for kw in POLICE_KWORDS:
        if re.search(kw, h, re.IGNORECASE):
            terms.append(kw)
            
    assert(len(terms) <= 6) # at most 6 labels
    terms.extend([''] * (6 - len(terms))) # pad to length 6
    assert(len(terms) == 6)
    
    for i, t in enumerate(terms):
        d["term" + str(i)] = t

# %%
# write overall dataset to csv because analysis is easiest in R

with open("labeled_dataset.csv", 'w') as outf:
    outf.write(",".join(sorted(d.keys())) + "\n")
    for d in labeled_dataset:
        outf.write(",".join(['"' + b.replace('"', r'\"') + '"' for a,b in sorted(list(d.items()))]) + "\n")

# %%
################################################################################
# From here onwards is random, sprawling analysis in python, ignore it.        #
#                                                                              #
# This is just a relic from late night work getting quick and dirty stats for  #
# presentation I had the next morning.                                         #
################################################################################

# %%
# general count of all data demographics

from collections import Counter

age_demogr_count = Counter()
gender_demogr_count = Counter()
race_demogr_count = Counter()
state_demogr_count = Counter()
demogr_counts = [age_demogr_count, gender_demogr_count, race_demogr_count, state_demogr_count]

for demogr_count, DEMO in zip(demogr_counts, DEMOGRAPHICS):
    for d in dataset:
        demogr = d[DEMO]
        
        if demogr == '':
            demogr = "Unknown " + DEMO
            
        demogr_count.update([demogr])

for demogr_count, DEMO in zip(demogr_counts, DEMOGRAPHICS):
    print("\n" + DEMO + "\n--------")
    print("\n".join([a + (( int((15 - len(a))/8)+1 )*"\t") + str(b) for a, b in demogr_count.most_common()]))
# Out:
# age
# --------
# 30 to 44	303
# 18 to 29	243
# 45 and up	203
# Unknown age	196
# Under 18	12
#
# gender
# --------
# Male		754
# Unknown gender	153
# Female		50
#
# race
# --------
# White		362
# Unknown race	239
# Black		207
# Hispanic	124
# Other race	25
#
# state
# --------
# California	107
# Texas		69
# Florida		69
# Arizona		43
# Colorado	42
# Georgia		41
# Ohio		36
# Tennessee	30
# Nevada		30
# Illinois	27
# Utah		26
# New Mexico	24
# North Carolina	24
# Missouri	23
# Pennsylvania	23
# Michigan	23
# Arkansas	21
# Washington	19
# New York	19
# Minnesota	19
# Hawaii		18
# New Jersey	18
# Iowa		17
# Virginia	17
# Oklahoma	17
# Kentucky	17
# Oregon		15
# Wisconsin	15
# Louisiana	14
# Maryland	13
# Indiana		12
# South Carolina	12
# Idaho		11
# Alabama		9
# Alaska		7
# Kansas		5
# Mississippi	5
# Maine		3
# Montana		3
# Massachusetts	3
# South Dakota	2
# New Hampshire	2
# North Dakota	2
# Connecticut	1
# Rhode Island	1
# Nebraska	1
# Wyoming		1
# D.C.		1

# %%
from collections import Counter

# make a dict with keys as PRP's and vals as sets of datapoints
deceas_PRP = {}
label_count = [0] * len(dataset)

# keys are labels and vals are counters
age_count = {}
gender_count = {}
race_count = {}
state_count = {}
demogr_counts = [age_count, gender_count, race_count, state_count]

# detect PRP's denoting the deceased
for i,d in enumerate(dataset):
    h = d["headline"]
    demogrs = [d["age"], d["gender"], d["race"], d["state"]]
    
    for kw in DECEAS_KWORDS:
        if re.search(kw, h, re.IGNORECASE):
            if kw not in deceas_PRP or not deceas_PRP[kw]:
                deceas_PRP[kw] = {h}
            else:
                deceas_PRP[kw].add(h)
            label_count[i] += 1
            
            for demogr_count, DEMO in zip(demogr_counts, DEMOGRAPHICS):
                demogr = d[DEMO]
                
                if kw not in demogr_count:
                    demogr_count[kw] = Counter([demogr])
                else:
                    demogr_count[kw].update([demogr])

unlabeled = []
overlabeled = []

unlabeled_age_count = Counter()
unlabeled_gender_count = Counter()
unlabeled_race_count = Counter()
unlabeled_state_count = Counter()
unlabeled_demogr_counts = [unlabeled_age_count, unlabeled_gender_count, \
                           unlabeled_race_count, unlabeled_state_count]

for i,d in enumerate(dataset):
    if label_count[i] == 0:
        unlabeled.append(d["headline"])
        
        for demogr_count, demogr in zip(unlabeled_demogr_counts, DEMOGRAPHICS):
            val = d[demogr]
            if val == '':
                val = "Unknown " + demogr
            demogr_count.update([val])

    elif label_count[i] > 1:
        overlabeled.append((label_count[i], d["headline"]))

#print("0  label:  " + str(len(unlabeled)))
#print("1  label:  " + str(len(label_count) - len(unlabeled) - len(overlabeled)))
#print("2+ labels: " + str(len(overlabeled))) # TODO hand correct

#print("\nlabel\t\t\t\t\tinstances\n-----\t\t\t\t\t---------")
#print("\n".join([a + ((int((31 - len(a))/8) + 2)*"\t") + str(len(b)) for a,b in deceas_PRP.items()]))

print("\n".join(unlabeled))
#print("\n".join([str(a) + ": " + b for a,b in overlabeled]))

#for demogr_count, demogr in zip(unlabeled_demogr_counts, DEMOGRAPHICS):
#    print("\n" + "unlabeled " + demogr + "\n--------")
#    print("\n".join(["\t" + a + (( int((15 - len(a))/8)+1 )*"\t") + str(b) for a, b in demogr_count.most_common()]))

#for demogr_count, demogr in zip(demogr_counts, DEMOGRAPHICS):
#    print("\n" + demogr + "\n--------")
#
#    for label, counter in demogr_count.items():
#        if '' in counter:
#            n = counter['']
#            del counter['']
#
#            key = "Unknown " + demogr
#            if key in counter:
#                counter[key] += n
#            else:
#                counter[key] = n
#
#        print(label)
#        print("\n".join(["\t" + a + (( int((15 - len(a))/8)+1 )*"\t") + str(b) for a, b in counter.most_common()]))
# Out:
# Officials to investigate use of deadly force by Webster County police on New Year's Eve
# One killed in St. Joseph officer-involved shooting
# Family speaks about loved one shot by Port Arthur police Friday
# Maui police release body camera footage of deadly officer-involved shooting
# Subject, officer in fatal Springfield officer-involved shooting ID'd
# Chase leads to fatal officer-involved shooting in Lake Elsinore
# Officer-Involved Shooting Reported In Lake Elsinore
# Phoenix police involved in shooting near 36th Street and Oak
# Probe ongoing in officer-involved shooting in Union City
# Investigation underway after deadly officer-involved shooting in Oklahoma City
# TBI Investigates Deadly MPD Officer-Involved Shooting
# 2 dead in separate Jacksonville police shootings Wednesday, 1 had BB gun
# One dead after officer-involved shooting in Washington County
# Dramatic video captures fatal officer-involved shooting Saturday in West Wendover
# One dead after Fort Pierce police officer-involved shooting
# The scene of an officer-involved shooting in Fort Pierce
# Fatal Officer-Involved Shooting In Pahrump, Bodycam Footage Released
# Nye sheriff releases body cam footage of fatal shooting
# Henry County police officer remains in critical condition after shooting
# 1 dead in Port Richmond officer-involved shooting
# Philadelphia Police Investigating Deadly Officer-Involved Shooting In Port Richmond
# FDLE continues to investigate deputy involved shooting in Escambia County
# Fatal shooting by western South Dakota deputy was justified, investigation finds
# Phoenix officer involved in shooting near 35th Ave/Thomas Rd, injuries unknown
# 1 dead after officer-involved shooting in Bemidji
# Body cam footage, IDs released following officer-involved shooting in southeast Louisville
# BCA investigates officer-involved shooting in Virginia
# BCA Investigating Fatal Virginia Officer-Involved Shooting
# Before fatal shooting, deputies used pit maneuver to stop stolen car near I-25 and Dry Creek
# Police officer-involved shooting death on Detroit freeway, Friday
# More details released in deadly officer-involved shooting in Bremen, KY
# Hoover offers deepest sympathies after deadly Alabama mall shooting, vows transparency
# Two dead, two officers injured in shootout at Talladega Walmart
# 2 dead in officer-involved shooting in Talladega
# 1 dead after officer-involved shooting in Franklinton
# Identities released in fatal officer-involved shooting in Stillwater
# 4 shooting deaths in 5 days in Magnolia shocks Arkansas's small town
# New details in Meridian officer-involved shooting
# Retired Police Officer Shoots at Cops, They Shoot Back and Kill Him
# State investigators probe fatal shooting incident with Missoula PD
# Ex-Alabama trooper shoots DA in face, is killed by police
# Video shows moments before deadly Butte County deputy-involved shooting
# UPDATE | Details emerge about deputy-involved deadly shooting at Augusta hotel
# Deputy-involved shooting in Wythe County under investigation
# Glendale Police investigating deadly officer involved shooting in Phoenix
# Phoenix officers identified in fatal Glendale police shooting
# Former police captain shot and killed by officer in northeast Fresno | The Fresno Bee
# OSBI Investigating Officer Involved Shooting In Wagoner
# MBI investigating officer-involved shooting in Clarksdale
# 2 killed in separate Utah police shootings identified
# ‘Everybody saw his back turned’: Newly released video of officers shooting Cody Belgard leaves family with more questions
# 911 transcript from Mpls. officer-involved shooting released
# Domestic Dispute Call Leads to Fatal Officer-Involved Shooting in Corona
# Deputy-involved fatal shooting at Charlotte Harbor McDonald's under investigation
# One dead after officer-involved shooting in southeast Albuquerque
# Officer-Involved Shooting At 24 Hour Fitness Gym
# Houston police release more information on fatal officer-involved shooting at Kingwood home
# 1 shot, killed by Snohomish Co. deputy after high-speed chase
# TBI investigating fatal officer-involved shooting in Cocke County
# One dead after officer-involved shooting in Gadsden County
# FBI responds to officer-involved shooting at Emerald Queen Casino
# Chandler police investigate deadly officer-involved shooting
# One Dead After Officer-Involved Shooting in Fort Smith
# Officers involved in deadly Rochester shooting rampage identified
# Officers involved in deadly Rochester shooting rampage identified
# Gunman shot by Milwaukee police during Oct. 10 confrontation dies
# TBI investigating officer-involved shooting in Oak Ridge
# New Mexico State Police investigating officer-involved shooting in Clovis
# NMSP investigate officer-involved shooting in Clovis
# Gunman killed, Nashville police officer injured in shooting late Friday night
# Domestic incident leads to barricade, officer-involved shooting in Bartlett
# 'Don't let anybody forget it'
# GBI looking into officer-involved shooting after Mableton hostage incident
# The three Orlando police officers involved in this week's fatal shooting at ORMC failed to use their body cameras
# What we know about fatal downtown Portland police shooting
# OSBI Investigating Deputy-Involved Shooting In Okmulgee County
# Newark Survivor In Police Shooting Charged With Weapon Offenses
# Peoria Police investigate fatal officer-involved shooting near Walmart
# Suspected shoplifter shot after firing at Peoria police took milk bottle
# HPD chief: Officers were executing search warrant before fatal shooting
# Gun pointed at police during shooting is registered to embattled Honolulu attorney
# Two shootings in two days: One killed in officer involved shooting, another dead by gunshot to head
# UPDATE: Body Cam Footage Released in Jacksonville Officer-Involved Shooting
# Ankeny police release identities in officer-involved shooting
# Family of David Huffines Jr. mourns after fatal shooting involving Mesa police
# Buffalo police investigating deadly officer-involved shooting
# Video of fatal officer-involved shooting seems to support police
# Greenville police release more information on deadly officer-involved shooting
# Police shooting follows deadly stabbing in Missouri City
# 1 dead after police-involved shooting in Hollywood
# Police: 2 dead, including Balloon Fiesta official. after Bernalillo officer-involved shooting
# Two die in Bernalillo KOA shooting
# ‘ER’ Actress Vanessa Marquez Shot, Killed By Police After Brandishing BB Gun
# Phoenix police involved in two deadly shootings early Monday morning
# Phoenix police involved in two deadly shootings early Monday morning
# Two dead after officer-involved shooting in southern Colorado
# Two killed in shootout with police in Alamosa
# One dead after police-involved shooting
# UPDATE: New details in Montgomery County deputy-involved shooting
# Officer injured in shooting "doing well," will have surgery
# Police, DA Investigating Fatal Officer-Involved Shooting
# One dead in officer involved shooting in Great Falls
# Supect dies after officer-involved shooting in Southeast Fresno
# Iowa officials investigating fatal officer-involved shooting
# 1 dead after after police-involved shooting in Richton Park
# Milwaukee police confirm second fatal officer-involved shooting in 3 weeks
# Milwaukee police confirm second fatal officer-involved shooting in 3 weeks
# Milwaukee Police Release Fatal Police Shooting Video
# LSP identifies individual killed in deputy involved shooting
# Gunman killed, officer wounded in Columbus police-involved shooting
# One dead in officer-involved shooting at Siena Francis House
# SPD involved shooting in Highland
# Commissioner: Deadly police-involved shooting in Germantown a tragedy
# Philadelphia police officer shot in face serving warrant in Germantown
# Metro Police investigating officer-involved shooting
# Sources ID Officers Involved In Fatal St. Paul Shooting
# ONLY ON: Camera captures deadly officer-involved shooting after SWAT standoff
# One dead after officer-involved shooting, one found dead in home
# 2 killed in Aurora shooting, one by officers
# 'Help us, not kill him:' Family called 911 before fatal officer-involved shooting in Moore County
# Video Released Of Deadly LAPD Officer-Involved Shooting In North Hills
# One dead in Savannah Police officer-involved shooting
# TBI Investigates Fatal Officer-Involved Shooting In Nashville
# Husband suspected in shooting death of wife dies after being shot by responding deputy
# Chief: Silver Lake Trader Joe’s Manager Was Killed by LAPD Gunfire
# Deadly officer involved shooting after standoff in West Central Fresno
# Five Peoria officers on paid leave after another fatal shooting
# Friends remember apparent unintended target in deadly officer-involved shooting
# SWAT standoff ends with deadly police shooting
# Authorities respond to deputy-involved shooting in Tucson
# Reno Police Investigate Officer-Involved Shooting in Sparks
# 1 dead after officer-involved shooting following chase
# Officer involved in shooting outside Alvin church
# KC Police shooting: The Latest: Details emerge on gunman's death, earlier case
# Florence mayor releases statement regarding officer-involved shooting
# Fatal Officer-Involved Shooting In Florence SC
# Chicago police release body camera footage of fatal officer-involved shooting that prompted protests
# Chicago police release video to ease tensions after killing Harith Augustus
# One dead in Dilley officer-involved shooting
# Minnetonka High School Student Shot, Killed By Police
# UPDATE: LVMPD identifies officers involved in recent shooting
# Cheyenne, Wyoming | News, Weather, Sports | CBS5 NewsChannel
# Officer Involved Shooting Reported In Garland
# 'Mental distress' call turns deadly after officer-involved shooting in Griffin
# Geneva, Kane Co. Officers Among Those Injured In Fatal Shooting
# Names released in Lawton officer-involved shooting
# One dead after officer-involved shooting in Panora, Iowa
# Injured Meridian officer 'recovering well,' released from hospital after traffic stop shootout
# 1 dead in Santa Ana officer-involved shooting
# Officers Fatally Shoot Suspected Car Burglar Near Santa Ana Police Department
# Officer named in North Pole trooper-involved shooting
# Shooting investigation continues
# LSP investigate officer-involved fatal shooting
# No charges to be filed in Chili's investigation
# GBI investigates Forsyth County deputy involved-shooting
# Neighbor recounts hostage situation that turned deadly in South Salt Lake
# Trenton arts festival had been on the verge of being shut down before gunfire
# Officer-involved shooting in Orange County under investigation
# 2 dead in officer-involved shooting near 12th, Wyandotte in downtown KC
# Kansas City police under fire after 3 fatal officer-involved shootings in an hour
# 2 dead in officer-involved shooting near 12th, Wyandotte in downtown KC
# Investigation begins into fatal officer-involved shooting in NJ
# Video shows deadly officer-involved shooting in central Phoenix
# Shooting involving local officers leaves one dead, one injured
# Officer-involved shooting in Hardwick under investigation
# Austin police investigating deadly officer involved shooting
# Salisbury Bank Robbery Chase Leads to Officer-Involved Shooting in Thomasville: Sheriff
# LAPD Releases Graphic Body Cam Footage Of Deadly Officer-Involved Shooting
# Prominent Westlake businessman shot by deputy on I-90 Thursday night dies
# Border Patrol agent fatally shoots female migrant, official says
# Officer-involved shooting investigated in Gurnee
# Officer-involved shooting investigation in Harlan County
# Serving Minden-Gardnerville and Carson Valley
# One reported dead, Douglas County deputy injured in officer-involved shooting
# Police Involved Shooting in Quincy Leaves One Dead
# Royal Oak Police have no plans to add body cameras after second fatal shooting
# Bossier police release details of officer-involved shooting
# Officer involved shooting in Clark County
# Officer-involved shooting in Clark County kills one
# 1 dead after officer-involved shooting at police station
# Exclusive video shows Orlando police open fire in fatal shooting at plaza
# Deadly officer-involved shooting under investigation in Guernsey County
# Scottsdale Police: 1 dead in officer-involved shooting
# Terre Haute police officer killed in shootout honored as a hero
# 1 dead after deputy-involved shooting in Alamance County
# 1 dead after officer-involved shooting in Macon Co.
# Suspected Burglar Fatally Shot by Police at Redlands Home
# One Killed In Officer-Involved Shooting; No Officers Hurt
# Suspected burglar killed in officer-involved shooting in Colorado Springs
# APD Investigating Officer-Involved Shooting
# APD investigating officer involved shooting on Harmony
# TBI investigating fatal shooting by Memphis police officer
# Neighbors React to Officer-Involved Shooting in Boone
# Boone Law Enforcement Officials Investigating Officer-Involved Shooting
# Two-county pursuit ends in fatal officer-involved shooting in Foresthill | The Sacramento Bee
# Officer-involved shooting leaves one critically injured in Cumberland County | Lexington Herald Leader
# OSBI will investigate Tishomingo officer-involved fatal shooting

# %%
# make a dict with keys as PRP's and vals as sets of datapoints

from collections import Counter

police_PRP = {}
label_count = [0] * len(dataset)

state_counts = {}

# detect PRP's denoting the police
for i,d in enumerate(dataset):
    h = d["headline"]
    state = d["state"]
    for kw in POLICE_KWORDS:
        if re.search(kw, h, re.IGNORECASE):
            if kw not in police_PRP or not police_PRP[kw]:
                police_PRP[kw] = {h}
            else:
                police_PRP[kw].add(h)
            label_count[i] += 1
            
            if kw not in state_counts:
                state_counts[kw] = Counter([state])
            else:
                state_counts[kw].update([state])
            
unlabeled = []
overlabeled = []

unlabeled_state_count = Counter()

for i,d in enumerate(dataset):
    if label_count[i] == 0:
        unlabeled.append(d["headline"])
        
        state = d["state"]
        if state == '':
            state = "Unknown state"
        unlabeled_state_count.update([state])
        
    elif label_count[i] > 1:
        overlabeled.append((label_count[i], d["headline"]))

#print("0  label:  " + str(len(unlabeled)))
#print("1  label:  " + str(len(label_count) - len(unlabeled) - len(overlabeled)))
#print("2+ labels: " + str(len(overlabeled))) # TODO hand correct

print("\n".join(unlabeled))
#print("\n".join([str(a) + ": " + b for a,b in overlabeled]))

#print("\nlabel\t\t\t\tinstances\n-----\t\t\t\t---------")
#print("\n".join([a + (int((31 - len(a))/8 + 1)*"\t") + str(len(b)) for a,b in police_PRP.items()]))

#print("\nunlabeled state\n--------")
#print("\n".join(["\t" + a + (( int((15 - len(a))/8)+1 )*"\t") + str(b) for a, b in unlabeled_state_count.most_common()]))

#for label, counter in state_counts.items():
#    if '' in counter:
#        n = counter['']
#        del counter['']
#
#        key = "Unknown state"
#        if key in counter:
#            counter[key] += n
#        else:
#            counter[key] = n
#
#    print("\n" + label + "\n--------")
#    print("\n".join(["\t" + a + (( int((15 - len(a))/8)+1 )*"\t") + str(b) for a, b in counter.most_common()]))
# Out:
# Shooting Victim in Carbon County Chase Dies; Four Arrested
# Nye sheriff releases body cam footage of fatal shooting
# Suspect killed in stolen car chase wanted for stealing show dogs
# Suspect killed in South Salt Lake critical incident Saturday identified
# Friends and family remember young man killed in Thanksgiving standoff
# Hoover offers deepest sympathies after deadly Alabama mall shooting, vows transparency
# 4 shooting deaths in 5 days in Magnolia shocks Arkansas's small town
# 1 Dead, Multiple Wounded in Watts Shooting; Suspect in Custody
# Details On Fatal Shooting Of Manahawkin Man Wanted In Kidnapping
# Mantoloking fatal shooting: Suspect served probation for assault; K9 back home
# Jesus “Chuy” Guzman Triple Murder Suspect Killed in Shootout
# SWAT team fatally shoots man during Osceola County standoff, sheriff says
# GBI identifies man shot, killed by cops outside Cobb apartment complex
# 'Don't let anybody forget it'
# Cops: Man fatally shoots girlfriend’s grandma before being killed by Cobb SWAT
# Kidnapping suspect with AK-47 is dead after shooting at cops near Miami airport | Bradenton Herald
# Two die in Bernalillo KOA shooting
# Suspect dead, cruiser riddled with bullet holes in South Philadelphia shooting
# Suspect identified in early-morning Nanakuli shootout
# Cheyenne, Wyoming | News, Weather, Sports | CBS5 NewsChannel
# Armed suspect fatally shot during Eustis standoff
# Shooting investigation continues
# Man Shot and Killed in Wayne County Standoff
# No charges to be filed in Chili's investigation
# Neighbor recounts hostage situation that turned deadly in South Salt Lake
# Trenton arts festival had been on the verge of being shut down before gunfire
# New Jersey art festival shooting suspect had just been released from prison, prosecutor says
# Suspect killed in ‘shootout’ in ABQ
# Manhunt for suspect after ATF agent shot in undercover gun buy operation
# Suspect who allegedly ambushed ATF agent during undercover operation is in custody: officials
# New Hanover Co. man fatally shot after standoff had outstanding warrants
# Double homicide suspect shot by sheriff, undersheriff outside Fort Morgan Walmart dies
# Morgan County SO: Knife-wielding double homicide suspect shot 7 times in Walmart parking lot
# As new details emerge, the Brett Luengo shot on I-90 is not the man loved ones knew
# Serving Minden-Gardnerville and Carson Valley
# Coroner: Shooting spree suspect dies; autopsy pending
# UPDATE: Knife-wielding man fatally shot in Tucson identified
# UPDATE: Fatally shot person in Yuma identified
# Friday Shooting Suspect Identified
# Authorities kill man after confrontation at Elk Grove hotel | The Sacramento Bee
# Chase from Oklahoma to Texas ends with kidnapper shot dead, his victim stabbed but alive
# Oklahoma suspect dead; alleged kidnapping, stabbing victim in serious but stable condition
# West Olive man and suspect in Muskegon homicide killed in standoff
# Chico man shot, killed after vehicle pursuit through Nevada, Placer counties

# %%
names = set()

# check for proper names
for d in dataset:
    if d["name"] == "An unidentified person":
        continue

    lastname = re.findall(r"\s(\w+)$", d["name"])
    
    if lastname:
        lastname = lastname[0]
        names.add(lastname)
        
        if re.search(lastname, d["headline"]):
            print(d["headline"])
            
            # only two hits, both false positives conflating county and surname
            
# TODO: for some reason my names are offset from their datapoints, but all the other
# demographics match up, have to fix this (should be able to join by all other features
# on fatal force csv and then migrate over name?)

# Less than 10 uses of victim name though:
# ----
# Family IDs Victim Of Deadly Shakopee Police Shooting As James Hanchett
# Jesus “Chuy” Guzman Triple Murder Suspect Killed in Shootout
# Dashcam video released of Halloween deputy-involved shooting that killed 17-year-old Jose Centeno Jr.
# Family IDs Hastings Police Shooting Victim As Keagan Johnson
# ‘ER’ Actress Vanessa Marquez Shot, Killed By Police After Brandishing BB Gun
# Woman Fatally Shot by Officers in South Pasadena ID’d as ‘ER’ Actress Vanessa Marquez
# As new details emerge, the Brett Luengo shot on I-90 is not the man loved ones knew
# Out:
# UPDATE: New details in Montgomery County deputy-involved shooting
# Mother doesn't blame Montgomery County deputies for son's death
# Person dead after officer-involved shooting in rural Webster County
# Officials to investigate use of deadly force by Webster County police on New Year's Eve
# Seattle police are reviewing video of fatal shooting of South King County father of two
# Police ID man killed in officer-involved shooting on Green Street
# Family speaks about loved one shot by Port Arthur police Friday
# Lakeland officers shoot, kill driver of stolen car in crowded parking lot
# Man suspected of killing his Warren grandmother dies in police scuffle
# Chase leads to fatal officer-involved shooting in Lake Elsinore
# Officer-Involved Shooting Reported In Lake Elsinore
# 2 dead in separate Jacksonville police shootings Wednesday, 1 had BB gun
# Officers In Western Colorado Kill Stolen Vehicle Suspect
# One dead after officer-involved shooting in Washington County
# Dramatic video captures fatal officer-involved shooting Saturday in West Wendover
# Police identify driver shot dead by officers following pursuit in West Wendover
# One dead after Fort Pierce police officer-involved shooting
# The scene of an officer-involved shooting in Fort Pierce
# Deputy Shoots, Kills Wanted Suspect Near Martinez
# Deputy Shoots, Kills Wanted Suspect Near Martinez
# Phoenix officer involved in shooting near 35th Ave/Thomas Rd, injuries unknown
# Police: Man dead after officer-involved shooting in Lakewood
# Lakewood officers fatally shoot armed suspect near 13th and Sheridan
# Police identify man killed in officer-involved shooting outside Clinton police station
# Man shot, killed in parking lot of Clinton Police Station
# Suspect killed in South Salt Lake critical incident Saturday identified
# Family of man who killed South Salt Lake police officer shares why they wrote letter to officer’s family
# Alabama NAACP strongly condemns Hoover police shooting of 21-year-old Emantic Bradford Jr.
# Alabama NAACP strongly condemns Hoover police shooting of 21-year-old Emantic Bradford Jr.
# Update: Knife-wielding man shot by police at West Main QuickTrip dies at hospital
# Man killed in officer-involved shooting in Clarksdale
# MBI investigating officer-involved shooting in Clarksdale
# Family IDs Victim Of Deadly Shakopee Police Shooting As James Hanchett
# One of two men shot by police Friday identified; investigations underway in Salt Lake City and Ogden
# ‘Everybody saw his back turned’: Newly released video of officers shooting Cody Belgard leaves family with more questions
# Jesus “Chuy” Guzman Triple Murder Suspect Killed in Shootout
# Dashcam video released of Halloween deputy-involved shooting that killed 17-year-old Jose Centeno Jr.
# Dashcam video released of Halloween deputy-involved shooting that killed 17-year-old Jose Centeno Jr.
# Jacksonville police kill carjacking suspect 1 day after getting out of jail
# Houston police release more information on fatal officer-involved shooting at Kingwood home
# Family of man killed by a Washington police officer considers hiring an attorney
# Man shot, killed by officers during Metro Gang Unit operation in Salt Lake City
# Deputies shoot, kill suspect in Hall County after SWAT standoff
# One Dead After Officer-Involved Shooting in Fort Smith
# Police identify man killed by officer after domestic violence call leads to altercation in West Jordan
# Police identify man killed by officer after domestic violence call leads to altercation in West Jordan
# UPDATE: Man shot by Bradford Co. Deputies Identified
# Family IDs Hastings Police Shooting Victim As Keagan Johnson
# Troopers identify man killed by Kentucky State Police in Whitley County
# UPDATE: Body Cam Footage Released in Jacksonville Officer-Involved Shooting
# Family of David Huffines Jr. mourns after fatal shooting involving Mesa police
# Family of David Huffines Jr. mourns after fatal shooting involving Mesa police
# Greenville police: Suspect killed in officer-involved shooting
# Greenville police release more information on deadly officer-involved shooting
# Suspect in Westminster dies after charging police with knife
# ‘ER’ Actress Vanessa Marquez Shot, Killed By Police After Brandishing BB Gun
# Woman Fatally Shot by Officers in South Pasadena ID’d as ‘ER’ Actress Vanessa Marquez
# UPDATE: New details in Montgomery County deputy-involved shooting
# Mother doesn't blame Montgomery County deputies for son's death
# Man in officer-involved shooting near Bakersfield dies
# Jeffrey Dennis identified as the Black man shot and killed by Northeast Philadelphia police
# One person dead in Baker County following police-involved shooting
# Baker County releases names of man shot, killed by deputies
# Suspect killed in Westminster officer-involved shooting identified
# Suspect dead after officer-involved shooting in Westminster
# 'Help us, not kill him:' Family called 911 before fatal officer-involved shooting in Moore County
# Moore County man killed by deputies did not fire shots, sheriff says
# Man shot by Lakemoor police was wanted for Pennsylvania murder, authorities say
# Man, 29, dies after Whitehaven officer-involved shooting; TBI investigation underway
# Bradford County sheriff names man shot, killed by 2 deputies
# Man Fatally Shot by Anaheim Police After Reports of Person Hallucinating
# Chief: Silver Lake Trader Joe’s Manager Was Killed by LAPD Gunfire
# Deadly officer involved shooting after standoff in West Central Fresno
# Man killed in shooting in Pico Rivera after pursuit with sheriff’s deputies
# Pico Rivera deputy-involved shooting: DUI suspect killed after pursuit ends in crash
# Police: Jacksonville officer shot, killed man who approached with knife
# Suspect identified in Devils Lake police shooting
# One person dead after officer-involved shooting in Devils Lake
# Lake deputies shoot armed man during standoff in Eustis
# Chicago cops fatally shoot armed man during chase on West Side, police say
# Man fatally shot by Chicago police in West Garfield Park identified
# Authorities: Kingsland police shoot and kill man following traffic stop
# Man, 33, shot, killed by Kingsland police, authorities say
# Police identify man who killed elderly woman during South Salt Lake standoff as her grandson
# Neighbor recounts hostage situation that turned deadly in South Salt Lake
# GBI identifies man killed in exchange of fire with Hall County deputies
# Man killed after firing ‘multiple gunshots’ at Hall County deputies, officials say
# Montgomery Co. police officer shoots, kills man in Silver Spring
# Suspect in bank robbery, officer-involved shooting in Thomasville dies
# Salisbury Bank Robbery Chase Leads to Officer-Involved Shooting in Thomasville: Sheriff
# Salisbury Bank Robbery Chase Leads to Officer-Involved Shooting in Thomasville: Sheriff
# Police fatally shoot woman accused of stabbing her therapist in Fullerton
# Breaking: Armed robbery suspect shot and killed by West Jordan police
# Breaking: Armed robbery suspect shot and killed by West Jordan police
# Robbery suspect killed in West Jordan officer-involved shooting identified
# Robbery suspect killed in West Jordan officer-involved shooting identified
# Prominent Westlake businessman shot by deputy on I-90 Thursday night dies
# As new details emerge, the Brett Luengo shot on I-90 is not the man loved ones knew
# DOJ identifies man killed by police as Joshua Gomoll of Kaukauna
# Suspect Killed in West Memphis Officer-Involved Shooting; I-40 Reopens
# Memphis man killed in officer-involved shooting on I-40 in West Memphis
# Dead man's identity & other details released in officer-involved shooting outside Martins Ferry
# Lake Mary police fatally shoot man after road rage incident
# Officer involved shooting in Clark County
# Officer-involved shooting in Clark County kills one
# Sheriff IDs suspect killed in Glade Spring, VA officer-involved shooting
# Man shot, killed during officer-involved shooting in Jim Wells County
# Officer-involved shooting leaves 28-year-old man dead in Jim Wells County
# West Olive man killed in officer involved shooting
# West Olive man and suspect in Muskegon homicide killed in standoff
# Tazewell Co. deputy shoots, kills gun-wielding man at rural Mackinaw home
# Mackinaw man killed by Tazewell Co. deputy identified
# Salt Lake City police fatally shoot man in Sugar House standoff
# Authorities identify man shot, killed by Salt Lake City Police after domestic violence call
# Video shows Salt Lake police shooting man as he steps off porch
